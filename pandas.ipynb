# %%
import pandas as pd 
import numpy as np
# Pandas has 2 main Data Structures wiz. Series(1-D list) and DataFrame(2-D df)
# collection of 1 or more "Series" makes a DataFrame

# %%
# Convert lists to DataFrame 

mylist = [["Apple", "Orange"],["Banana", "Yellow"],["Orange", "Orange"]]

df = pd.DataFrame(mylist)
df

# columns and rows given default values.
# Out:
#         0       1
# 0   Apple  Orange
# 1  Banana  Yellow
# 2  Orange  Orange

# %%
mylist = [["Apple", "Orange"],["Banana", "Yellow"],["Orange", "Orange"]]

df = pd.DataFrame(mylist, columns=["Fruit", "Colour"], index=[1,2,3]) 
df                     # naming columns and rows(indexes)
# Out:
#     Fruit  Colour
# 1   Apple  Orange
# 2  Banana  Yellow
# 3  Orange  Orange

# %%
# DataFrame using numpy array. 

list = np.array([[1,2],[3,4],[5,6]])
df1 = pd.DataFrame(list, columns=["odd", "even"], index=[1,2,3])
df1
# Out:
#    odd  even
# 1    1     2
# 2    3     4
# 3    5     6

# %%
# DataFrame using Dictionary

data = {'Vorname':['Sarthak',"Pulkit"],'Nachname':['Bhardwaj','Bhardwaj'],'Alter':[23,27]}
df2 = pd.DataFrame(data, index=[1,2])               # keys become column headings
df2                                                 # values become rows
# Out:
#    Vorname  Nachname  Alter
# 1  Sarthak  Bhardwaj     23
# 2   Pulkit  Bhardwaj     27

# %%
# DataFrame from CSV

df = pd.read_csv('climate_change_data.csv')

df.set_index("Year", inplace=True) 
df                                 # set index using "inplace"
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2000              24.1           0.42               25.1
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
# 2001              24.4           0.44               25.4
# 2006              26.5           0.49               28.7
# 2011              29.3           0.55               33.4
# 2016              32.5           0.63               39.7
# 2021              35.0           0.92               45.8
# 2002              24.5           0.45               25.5
# 2007              26.7           0.50               29.0
# 2012              29.4           0.56               33.8
# 2017              32.8           0.64               40.1
# 2022              35.4           0.93               46.3
#
#       Deforestation_Rate_Ha
# Year
# ...

# %%
df.head(2)              # print head of the dataframe
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2000              24.1           0.42               25.1
# 2005              26.3           0.48               28.5
#
#       Deforestation_Rate_Ha
# Year
# 2000                    9.2
# 2005                    8.9

# %%
df.tail(2)              # print tail of the dataframe
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2017              32.8           0.64               40.1
# 2022              35.4           0.93               46.3
#
#       Deforestation_Rate_Ha
# Year
# 2017                    8.3
# 2022                    8.0

# %%
# Statistical summary of the DataFrame

df.describe
# Out:
# <bound method NDFrame.describe of       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2000              24.1           0.42               25.1
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
# 2001              24.4           0.44               25.4
# 2006              26.5           0.49               28.7
# 2011              29.3           0.55               33.4
# 2016              32.5           0.63               39.7
# 2021              35.0           0.92               45.8
# 2002              24.5           0.45               25.5
# 2007              26.7           0.50               29.0
# 2012              29.4           0.56               33.8
# 2017              32.8           0.64               40.1
# 2022              35.4           0.93               46.3
#
# ...

# %%
df[1:6] # [inclusive:exclusive]                               # Row slicing
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
# 2001              24.4           0.44               25.4
#
#       Deforestation_Rate_Ha
# Year
# 2005                    8.9
# 2010                    8.7
# 2015                    8.5
# 2020                    8.2
# 2001                    9.1

# %%
df[["CO2_Emissions_Gt", "Global_Temp_C"]] # Indexing columns using bracket operator
# Out:
#       CO2_Emissions_Gt  Global_Temp_C
# Year
# 2000              24.1           0.42
# 2005              26.3           0.48
# 2010              29.1           0.54
# 2015              32.1           0.61
# 2020              34.5           0.89
# 2001              24.4           0.44
# 2006              26.5           0.49
# 2011              29.3           0.55
# 2016              32.5           0.63
# 2021              35.0           0.92
# 2002              24.5           0.45
# 2007              26.7           0.50
# 2012              29.4           0.56
# 2017              32.8           0.64
# 2022              35.4           0.93

# %%
df = df[0:5]
df
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2000              24.1           0.42               25.1
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
#
#       Deforestation_Rate_Ha
# Year
# 2000                    9.2
# 2005                    8.9
# 2010                    8.7
# 2015                    8.5
# 2020                    8.2

# %%
thirdRow = [False, False, True, False, False]    # Boolean Lists 
df[thirdRow]           # iterate through the indexes and print the desired index.
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2010              29.1           0.54               33.0
#
#       Deforestation_Rate_Ha
# Year
# 2010                    8.7

# %%
df
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2000              24.1           0.42               25.1
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
#
#       Deforestation_Rate_Ha
# Year
# 2000                    9.2
# 2005                    8.9
# 2010                    8.7
# 2015                    8.5
# 2020                    8.2

# %%
condition1 = df["CO2_Emissions_Gt"] > 25    # apply conditions on columns to filter data.
df[condition1]
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
#
#       Deforestation_Rate_Ha
# Year
# 2005                    8.9
# 2010                    8.7
# 2015                    8.5
# 2020                    8.2

# %%
df[(df["CO2_Emissions_Gt"] > 25) & (df["Deforestation_Rate_Ha"] > 8.5)] # grouping conditions using & operator
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
#
#       Deforestation_Rate_Ha
# Year
# 2005                    8.9
# 2010                    8.7

# %%
df[(df["Global_Temp_C"] > 0.50) | (df["Sea_Level_Rise_mm"] > 30.0 )]  # grouping conditions using & operator
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
#
#       Deforestation_Rate_Ha
# Year
# 2010                    8.7
# 2015                    8.5
# 2020                    8.2

# %%
df
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2000              24.1           0.42               25.1
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
#
#       Deforestation_Rate_Ha
# Year
# 2000                    9.2
# 2005                    8.9
# 2010                    8.7
# 2015                    8.5
# 2020                    8.2

# %%
df.loc[2005:2015, 'CO2_Emissions_Gt' : 'Sea_Level_Rise_mm']  # Filter data using loc()
        #Slice rows        #Slice Columns
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm
# Year
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3

# %%
df.loc[[2000,2010,2020],  ['Global_Temp_C','Deforestation_Rate_Ha']]   # hand-picking
    # Indexing rows            # Indexing Columns
# Out:
#       Global_Temp_C  Deforestation_Rate_Ha
# Year
# 2000           0.42                    9.2
# 2010           0.54                    8.7
# 2020           0.89                    8.2

# %%
df
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2000              24.1           0.42               25.1
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
#
#       Deforestation_Rate_Ha
# Year
# 2000                    9.2
# 2005                    8.9
# 2010                    8.7
# 2015                    8.5
# 2020                    8.2

# %%
df.iloc[4,2] # locate individual position 
#[Row, Column] 
# only indexes no value of cell
# Out:
# np.float64(45.0)

# %%
df.iloc[0:3,0:2] #Slicing using iloc()
# Out:
#       CO2_Emissions_Gt  Global_Temp_C
# Year
# 2000              24.1           0.42
# 2005              26.3           0.48
# 2010              29.1           0.54

# %%
df
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2000              24.1           0.42               25.1
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
#
#       Deforestation_Rate_Ha
# Year
# 2000                    9.2
# 2005                    8.9
# 2010                    8.7
# 2015                    8.5
# 2020                    8.2

# %%
df.loc[5] = [35.3, 0.92, 45.8, 8.1]
df
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2000              24.1           0.42               25.1
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
# 2025              35.3           0.92               45.8
# 5                 35.3           0.92               45.8
#
#       Deforestation_Rate_Ha
# Year
# 2000                    9.2
# 2005                    8.9
# 2010                    8.7
# 2015                    8.5
# 2020                    8.2
# 2025                    8.1
# 5                       8.1

# %%
df.drop(5, axis=0, inplace=True)
df
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2000              24.1           0.42               25.1
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
# 2025              35.3           0.92               45.8
#
#       Deforestation_Rate_Ha
# Year
# 2000                    9.2
# 2005                    8.9
# 2010                    8.7
# 2015                    8.5
# 2020                    8.2
# 2025                    8.1

# %%
df["Soil_Erosion_mm"] = [2,3,4.3,4,5.8,7]    # append new column 
df
# Out:
#       CO2_Emissions_Gt  Global_Temp_C  Sea_Level_Rise_mm  \
# Year
# 2000              24.1           0.42               25.1
# 2005              26.3           0.48               28.5
# 2010              29.1           0.54               33.0
# 2015              32.1           0.61               39.3
# 2020              34.5           0.89               45.0
# 2025              35.3           0.92               45.8
#
#       Deforestation_Rate_Ha  Soil_Erosion_mm
# Year
# 2000                    9.2              2.0
# 2005                    8.9              3.0
# 2010                    8.7              4.3
# 2015                    8.5              4.0
# 2020                    8.2              5.8
# 2025                    8.1              7.0

# %%
df.drop('CO2_Emissions_Gt', axis=1, inplace=True)    # drop column 
df
# Out:
#       Global_Temp_C  Sea_Level_Rise_mm  Deforestation_Rate_Ha  Soil_Erosion_mm
# Year
# 2000           0.42               25.1                    9.2              2.0
# 2005           0.48               28.5                    8.9              3.0
# 2010           0.54               33.0                    8.7              4.3
# 2015           0.61               39.3                    8.5              4.0
# 2020           0.89               45.0                    8.2              5.8
# 2025           0.92               45.8                    8.1              7.0

# %%
df.sort_values (by= 'Deforestation_Rate_Ha' , ascending=True)   # sort alphabetically or numerically
# Out:
#       Global_Temp_C  Sea_Level_Rise_mm  Deforestation_Rate_Ha  Soil_Erosion_mm
# Year
# 2025           0.92               45.8                    8.1              7.0
# 2020           0.89               45.0                    8.2              5.8
# 2015           0.61               39.3                    8.5              4.0
# 2010           0.54               33.0                    8.7              4.3
# 2005           0.48               28.5                    8.9              3.0
# 2000           0.42               25.1                    9.2              2.0

# %%
df.to_csv('myFile.csv')              # export code to csv

# %%
newdf = pd.read_csv('myFile.csv')                         # read csv
newdf
# Out:
#    Year  Global_Temp_C  Sea_Level_Rise_mm  Deforestation_Rate_Ha  \
# 0  2000           0.42               25.1                    9.2
# 1  2005           0.48               28.5                    8.9
# 2  2010           0.54               33.0                    8.7
# 3  2015           0.61               39.3                    8.5
# 4  2020           0.89               45.0                    8.2
# 5  2025           0.92               45.8                    8.1
#
#    Soil_Erosion_mm
# 0              2.0
# 1              3.0
# 2              4.3
# 3              4.0
# 4              5.8
# 5              7.0

# %%
#pd.concat([pd1,pd2], axis = 1)                        # concatination

# %%
# df.groupby(['Year']).sum()              # group the data from a column and perform various operations.
